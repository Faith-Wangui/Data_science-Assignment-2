# %%
import os
print("Files in /content right now:")
print(os.listdir('/content'))
# Out:
# Files in /content right now:
# ['.config', 'road_accidents_dataset.xlsx', 'sample_data']

# %%
import pandas as pd

# Load your Excel file
df = pd.read_excel('/content/road_accidents_dataset.xlsx')

# Show the first few rows and columns
df.head()
# Out:
#    vehicle_count  speed_limit           road_type weather light_condition  \
# 0              2           80  single_carriageway   clear        daylight
# 1              3           60    dual_carriageway    rain           night
# 2              1           40               urban   clear        daylight
# 3              4          100             highway   clear        daylight
# 4              2           70    dual_carriageway     fog        daylight
#
#    hour  driver_age vehicle_type  alcohol_involved  severity
# 0    15          32          car                 0         2
# 1    22          45        truck                 1         3
# 2     9          25   motorcycle                 0         1
# 3    14          38          car                 0         2
# 4    10          40          van                 0         2

# %%
joblib.dump(model, 'road_severity_model.joblib')
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
sample = pd.DataFrame({
    'vehicle_count': [3],
    'speed_limit': [80],
    'hour': [18],
    'driver_age': [35],
    'alcohol_involved': [1]
})

prediction = model.predict(sample)
print("Predicted Severity:", prediction[0])
# Out:
# Predicted Severity: 3.0749760100715124

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred)
plt.xlabel('Actual Severity')
plt.ylabel('Predicted Severity')
plt.title('Actual vs Predicted Accident Severity')
plt.show()
